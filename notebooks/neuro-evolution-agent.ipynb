# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from vctr.data.data_loader import get_data
df = get_data('NEAR', '1h', start='2023-01-01')
df.head()
# Out:
#                                  volume    open  close    high    low
# date
# 2023-01-01 00:00:00+00:00  35112.236648  1.2591  1.246  1.2591  1.245
# 2023-01-01 01:00:00+00:00   3550.805450  1.2450  1.247  1.2483  1.241
# 2023-01-01 02:00:00+00:00   4103.217324  1.2460  1.250  1.2547  1.243
# 2023-01-01 03:00:00+00:00   7710.705565  1.2490  1.250  1.2541  1.245
# 2023-01-01 04:00:00+00:00   6979.635536  1.2500  1.239  1.2539  1.239

# %%
close = df.close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('hour %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'hour %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            fitnesses = [i.fitness for i in self.population]
            sort_fitness = np.argsort(fitnesses)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(50)
# Out:
# epoch 5, fittest individual 0 with accuracy 0.107544
# epoch 10, fittest individual 0 with accuracy 0.107544
# epoch 15, fittest individual 0 with accuracy 0.107544
# epoch 20, fittest individual 0 with accuracy 0.107544
# epoch 25, fittest individual 0 with accuracy 0.191691
# epoch 30, fittest individual 0 with accuracy 0.191691
# epoch 35, fittest individual 0 with accuracy 0.191691
# epoch 40, fittest individual 0 with accuracy 0.191691
# epoch 45, fittest individual 0 with accuracy 0.191691
# epoch 50, fittest individual 0 with accuracy 0.191691

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# hour 1: buy 1 unit at price 1.247000, total balance 9998.753000
# hour 2: buy 1 unit at price 1.250000, total balance 9997.503000
# hour 5, sell 1 unit at price 1.243000, investment -0.320770 %, total balance 9998.746000,
# hour 6, sell 1 unit at price 1.244000, investment -0.480000 %, total balance 9999.990000,
# hour 7: buy 1 unit at price 1.244000, total balance 9998.746000
# hour 9, sell 1 unit at price 1.248000, investment 0.321543 %, total balance 9999.994000,
# hour 10: buy 1 unit at price 1.249000, total balance 9998.745000
# hour 12, sell 1 unit at price 1.256000, investment 0.560448 %, total balance 10000.001000,
# hour 14: buy 1 unit at price 1.253000, total balance 9998.748000
# hour 15, sell 1 unit at price 1.255000, investment 0.159617 %, total balance 10000.003000,
# hour 16: buy 1 unit at price 1.261100, total balance 9998.741900
# hour 18: buy 1 unit at price 1.274000, total balance 9997.467900
# hour 19: buy 1 unit at price 1.277000, total balance 9996.190900
# hour 20: buy 1 unit at price 1.277000, total balance 9994.913900
# hour 21: buy 1 unit at price 1.281300, total balance 9993.632600
# hour 22: buy 1 unit at price 1.273000, total balance 9992.359600
# hour 23, sell 1 unit at price 1.274000, investment 1.022917 %, total balance 9993.633600,
# hour 24, sell 1 unit at price 1.273800, investment -0.015699 %, total balance 9994.907400,
# hour 26: buy 1 unit at price 1.264000, total balance 9993.643400
# hour 27, sell 1 unit at price 1.272000, investment -0.391543 %, total balance 9994.915400,
# hour 30, sell 1 unit at price 1.276000, investment -0.078309 %, total balance 9996.191400,
# hour 31: buy 1 unit at price 1.301000, total balance 9994.890400
# hour 34: buy 1 unit at price 1.306000, total balance 9993.584400
# hour 35: buy 1 unit at price 1.310000, total balance 9992.274400
# hour 36: buy 1 unit at price 1.314900, total balance 9990.959500
# hour 38: buy 1 unit at price 1.317000, total balance 9989.642500
# hour 40: buy 1 unit at price 1.311000, total balance 9988.331500
# hour 41: buy 1 unit at price 1.321000, total balance 9987.010500
# hour 42, sell 1 unit at price 1.316000, investment 2.708187 %, total balance 9988.326500,
# hour 44, sell 1 unit at price 1.319000, investment 3.613511 %, total balance 9989.645500,
# hour 45, sell 1 unit at price 1.320000, investment 4.430380 %, total balance 9990.965500,
# hour 47: buy 1 unit at price 1.315200, total balance 9989.650300
# hour 48: buy 1 unit at price 1.317000, total balance 9988.333300
# hour 51: buy 1 unit at price 1.310000, total balance 9987.023300
# hour 52: buy 1 unit at price 1.308000, total balance 9985.715300
# hour 53, sell 1 unit at price 1.316000, investment 1.152959 %, total balance 9987.031300,
# hour 54, sell 1 unit at price 1.327000, investment 1.607963 %, total balance 9988.358300,
# hour 57: buy 1 unit at price 1.347000, total balance 9987.011300
# hour 60: buy 1 unit at price 1.331000, total balance 9985.680300
# hour 61: buy 1 unit at price 1.335000, total balance 9984.345300
# hour 63: buy 1 unit at price 1.341000, total balance 9983.004300
# hour 64, sell 1 unit at price 1.327000, investment 1.297710 %, total balance 9984.331300,
# hour 65, sell 1 unit at price 1.313000, investment -0.144498 %, total balance 9985.644300,
# hour 66, sell 1 unit at price 1.311000, investment -0.455581 %, total balance 9986.955300,
# hour 67: buy 1 unit at price 1.319000, total balance 9985.636300
# hour 68, sell 1 unit at price 1.316000, investment 0.381388 %, total balance 9986.952300,
# hour 69, sell 1 unit at price 1.322000, investment 0.075700 %, total balance 9988.274300,
# hour 70: buy 1 unit at price 1.323000, total balance 9986.951300
# hour 71: buy 1 unit at price 1.334000, total balance 9985.617300
# hour 72: buy 1 unit at price 1.336000, total balance 9984.281300
# hour 73: buy 1 unit at price 1.358700, total balance 9982.922600
# hour 74: buy 1 unit at price 1.442000, total balance 9981.480600
# hour 77: buy 1 unit at price 1.435000, total balance 9980.045600
# hour 78: buy 1 unit at price 1.469000, total balance 9978.576600
# hour 81: buy 1 unit at price 1.521000, total balance 9977.055600
# hour 83: buy 1 unit at price 1.499000, total balance 9975.556600
# hour 84: buy 1 unit at price 1.521000, total balance 9974.035600
# hour 85, sell 1 unit at price 1.520000, investment 15.571776 %, total balance 9975.555600,
# hour 89, sell 1 unit at price 1.596000, investment 21.184510 %, total balance 9977.151600,
# hour 91: buy 1 unit at price 1.565000, total balance 9975.586600
# hour 93: buy 1 unit at price 1.553000, total balance 9974.033600
# hour 94: buy 1 unit at price 1.540000, total balance 9972.493600
# hour 96, sell 1 unit at price 1.528000, investment 16.641221 %, total balance 9974.021600,
# hour 97: buy 1 unit at price 1.554000, total balance 9972.467600
# hour 99, sell 1 unit at price 1.554000, investment 18.807339 %, total balance 9974.021600,
# hour 100, sell 1 unit at price 1.596000, investment 18.485523 %, total balance 9975.617600,
# hour 102: buy 1 unit at price 1.576000, total balance 9974.041600
# hour 104: buy 1 unit at price 1.566800, total balance 9972.474800
# hour 107: buy 1 unit at price 1.566000, total balance 9970.908800
# hour 110: buy 1 unit at price 1.540000, total balance 9969.368800
# hour 111, sell 1 unit at price 1.540000, investment 15.702479 %, total balance 9970.908800,
# hour 113, sell 1 unit at price 1.543000, investment 15.580524 %, total balance 9972.451800,
# hour 114, sell 1 unit at price 1.547000, investment 15.361670 %, total balance 9973.998800,
# hour 115: buy 1 unit at price 1.554100, total balance 9972.444700
# hour 116: buy 1 unit at price 1.548000, total balance 9970.896700
# hour 117: buy 1 unit at price 1.542000, total balance 9969.354700
# hour 119, sell 1 unit at price 1.523000, investment 15.466262 %, total balance 9970.877700,
# hour 120: buy 1 unit at price 1.540000, total balance 9969.337700
# hour 121, sell 1 unit at price 1.534000, investment 15.948602 %, total balance 9970.871700,
# hour 122, sell 1 unit at price 1.534000, investment 14.992504 %, total balance 9972.405700,
# hour 123: buy 1 unit at price 1.526000, total balance 9970.879700
# hour 125, sell 1 unit at price 1.511000, investment 13.098802 %, total balance 9972.390700,
# hour 126, sell 1 unit at price 1.497000, investment 10.178847 %, total balance 9973.887700,
# hour 128, sell 1 unit at price 1.504000, investment 4.299584 %, total balance 9975.391700,
# hour 129: buy 1 unit at price 1.499000, total balance 9973.892700
# hour 130, sell 1 unit at price 1.489000, investment 3.763066 %, total balance 9975.381700,
# hour 131, sell 1 unit at price 1.487000, investment 1.225323 %, total balance 9976.868700,
# hour 132, sell 1 unit at price 1.489000, investment -2.103879 %, total balance 9978.357700,
# hour 133, sell 1 unit at price 1.508200, investment 0.613742 %, total balance 9979.865900,
# hour 134, sell 1 unit at price 1.501000, investment -1.314924 %, total balance 9981.366900,
# hour 135, sell 1 unit at price 1.522000, investment -2.747604 %, total balance 9982.888900,
# hour 136: buy 1 unit at price 1.518000, total balance 9981.370900
# hour 137, sell 1 unit at price 1.513000, investment -2.575660 %, total balance 9982.883900,
# hour 138: buy 1 unit at price 1.559000, total balance 9981.324900
# hour 141, sell 1 unit at price 1.551000, investment 0.714286 %, total balance 9982.875900,
# hour 142: buy 1 unit at price 1.580000, total balance 9981.295900
# hour 144: buy 1 unit at price 1.587000, total balance 9979.708900
# hour 145, sell 1 unit at price 1.591000, investment 2.380952 %, total balance 9981.299900,
# hour 146: buy 1 unit at price 1.577000, total balance 9979.722900
# hour 147: buy 1 unit at price 1.585100, total balance 9978.137800
# hour 148: buy 1 unit at price 1.567000, total balance 9976.570800
# hour 150: buy 1 unit at price 1.562200, total balance 9975.008600
# hour 152: buy 1 unit at price 1.552000, total balance 9973.456600
# hour 153, sell 1 unit at price 1.555000, investment -1.332487 %, total balance 9975.011600,
# hour 154, sell 1 unit at price 1.556000, investment -0.689303 %, total balance 9976.567600,
# hour 157, sell 1 unit at price 1.551100, investment -0.951469 %, total balance 9978.118700,
# hour 158: buy 1 unit at price 1.559000, total balance 9976.559700
# hour 161: buy 1 unit at price 1.554000, total balance 9975.005700
# hour 162: buy 1 unit at price 1.556000, total balance 9973.449700
# hour 164: buy 1 unit at price 1.573000, total balance 9971.876700
# hour 167: buy 1 unit at price 1.559000, total balance 9970.317700
# hour 170, sell 1 unit at price 1.537000, investment -0.194805 %, total balance 9971.854700,
# hour 171: buy 1 unit at price 1.544400, total balance 9970.310300
# hour 172, sell 1 unit at price 1.565000, investment 0.701371 %, total balance 9971.875300,
# hour 173, sell 1 unit at price 1.555000, investment 0.452196 %, total balance 9973.430300,
# hour 174, sell 1 unit at price 1.558000, investment 1.037613 %, total balance 9974.988300,
# hour 175: buy 1 unit at price 1.549000, total balance 9973.439300
# hour 176, sell 1 unit at price 1.559000, investment 1.233766 %, total balance 9974.998300,
# hour 177: buy 1 unit at price 1.571000, total balance 9973.427300
# hour 179, sell 1 unit at price 1.561000, investment 2.293578 %, total balance 9974.988300,
# hour 181: buy 1 unit at price 1.567800, total balance 9973.420500
# hour 182: buy 1 unit at price 1.595000, total balance 9971.825500
# hour 183: buy 1 unit at price 1.595000, total balance 9970.230500
# hour 184, sell 1 unit at price 1.589000, investment 6.004003 %, total balance 9971.819500,
# hour 185, sell 1 unit at price 1.590000, investment 4.743083 %, total balance 9973.409500,
# hour 186: buy 1 unit at price 1.599500, total balance 9971.810000
# hour 187, sell 1 unit at price 1.597000, investment 2.437460 %, total balance 9973.407000,
# hour 189: buy 1 unit at price 1.614000, total balance 9971.793000
# hour 191: buy 1 unit at price 1.647000, total balance 9970.146000
# hour 192: buy 1 unit at price 1.689000, total balance 9968.457000
# hour 193: buy 1 unit at price 1.698000, total balance 9966.759000
# hour 195: buy 1 unit at price 1.685000, total balance 9965.074000
# hour 196: buy 1 unit at price 1.702000, total balance 9963.372000
# hour 197: buy 1 unit at price 1.675000, total balance 9961.697000
# hour 199, sell 1 unit at price 1.677300, investment 6.158228 %, total balance 9963.374300,
# hour 200: buy 1 unit at price 1.664000, total balance 9961.710300
# hour 201: buy 1 unit at price 1.688000, total balance 9960.022300
# hour 203, sell 1 unit at price 1.675000, investment 5.545054 %, total balance 9961.697300,
# hour 205: buy 1 unit at price 1.658000, total balance 9960.039300
# hour 206, sell 1 unit at price 1.669000, investment 5.833862 %, total balance 9961.708300,
# hour 208: buy 1 unit at price 1.692000, total balance 9960.016300
# hour 210: buy 1 unit at price 1.676000, total balance 9958.340300
# hour 211: buy 1 unit at price 1.665000, total balance 9956.675300
# hour 212: buy 1 unit at price 1.644000, total balance 9955.031300
# hour 213, sell 1 unit at price 1.635000, investment 3.148066 %, total balance 9956.666300,
# hour 214, sell 1 unit at price 1.640000, investment 4.658583 %, total balance 9958.306300,
# hour 216: buy 1 unit at price 1.662000, total balance 9956.644300
# hour 218, sell 1 unit at price 1.611000, investment 3.123800 %, total balance 9958.255300,
# hour 219, sell 1 unit at price 1.622000, investment 4.510309 %, total balance 9959.877300,
# hour 220, sell 1 unit at price 1.633300, investment 4.765876 %, total balance 9961.510600,
# hour 222, sell 1 unit at price 1.637000, investment 5.341055 %, total balance 9963.147600,
# hour 223, sell 1 unit at price 1.630000, investment 4.755784 %, total balance 9964.777600,
# hour 224: buy 1 unit at price 1.642000, total balance 9963.135600
# hour 226: buy 1 unit at price 1.642000, total balance 9961.493600
# hour 227: buy 1 unit at price 1.625000, total balance 9959.868600
# hour 228, sell 1 unit at price 1.608000, investment 2.225048 %, total balance 9961.476600,
# hour 229, sell 1 unit at price 1.616000, investment 3.656190 %, total balance 9963.092600,
# hour 230: buy 1 unit at price 1.623300, total balance 9961.469300
# hour 231, sell 1 unit at price 1.634000, investment 5.801606 %, total balance 9963.103300,
# hour 232: buy 1 unit at price 1.622000, total balance 9961.481300
# hour 234, sell 1 unit at price 1.645000, investment 6.197547 %, total balance 9963.126300,
# hour 235, sell 1 unit at price 1.656000, investment 5.410567 %, total balance 9964.782300,
# hour 236: buy 1 unit at price 1.661900, total balance 9963.120400
# hour 237: buy 1 unit at price 1.651000, total balance 9961.469400
# hour 239: buy 1 unit at price 1.642000, total balance 9959.827400
# hour 240: buy 1 unit at price 1.640000, total balance 9958.187400
# hour 241, sell 1 unit at price 1.639000, investment 4.541396 %, total balance 9959.826400,
# hour 242, sell 1 unit at price 1.610000, investment 0.940439 %, total balance 9961.436400,
# hour 244: buy 1 unit at price 1.590000, total balance 9959.846400
# hour 245, sell 1 unit at price 1.595000, investment 0.000000 %, total balance 9961.441400,
# hour 246, sell 1 unit at price 1.605000, investment 0.343857 %, total balance 9963.046400,
# hour 247, sell 1 unit at price 1.610000, investment -0.247831 %, total balance 9964.656400,
# hour 248: buy 1 unit at price 1.602000, total balance 9963.054400
# hour 249, sell 1 unit at price 1.603000, investment -2.671524 %, total balance 9964.657400,
# hour 250, sell 1 unit at price 1.603000, investment -5.091770 %, total balance 9966.260400,
# hour 252, sell 1 unit at price 1.588000, investment -6.478210 %, total balance 9967.848400,
# hour 254: buy 1 unit at price 1.582000, total balance 9966.266400
# hour 256, sell 1 unit at price 1.559000, investment -7.477745 %, total balance 9967.825400,
# hour 257, sell 1 unit at price 1.563000, investment -8.166863 %, total balance 9969.388400,
# hour 258: buy 1 unit at price 1.584000, total balance 9967.804400
# hour 259: buy 1 unit at price 1.686000, total balance 9966.118400
# hour 262: buy 1 unit at price 1.806000, total balance 9964.312400
# hour 263: buy 1 unit at price 1.819000, total balance 9962.493400
# hour 265: buy 1 unit at price 1.826000, total balance 9960.667400
# hour 267: buy 1 unit at price 1.809000, total balance 9958.858400
# hour 269: buy 1 unit at price 1.769600, total balance 9957.088800
# hour 270: buy 1 unit at price 1.781000, total balance 9955.307800
# hour 271, sell 1 unit at price 1.769000, investment 5.611940 %, total balance 9957.076800,
# hour 272, sell 1 unit at price 1.759000, investment 5.709135 %, total balance 9958.835800,
# hour 273: buy 1 unit at price 1.762400, total balance 9957.073400
# hour 274, sell 1 unit at price 1.774000, investment 5.094787 %, total balance 9958.847400,
# hour 275: buy 1 unit at price 1.777000, total balance 9957.070400
# hour 277: buy 1 unit at price 1.826000, total balance 9955.244400
# hour 280: buy 1 unit at price 1.800000, total balance 9953.444400
# hour 281, sell 1 unit at price 1.830000, investment 10.373945 %, total balance 9955.274400,
# hour 283: buy 1 unit at price 1.847000, total balance 9953.427400
# hour 284: buy 1 unit at price 1.871500, total balance 9951.555900
# hour 288: buy 1 unit at price 1.813000, total balance 9949.742900
# hour 292: buy 1 unit at price 1.824000, total balance 9947.918900
# hour 293, sell 1 unit at price 1.802000, investment 6.501182 %, total balance 9949.720900,
# hour 294: buy 1 unit at price 1.815000, total balance 9947.905900
# hour 295, sell 1 unit at price 1.814000, investment 8.233890 %, total balance 9949.719900,
# hour 296: buy 1 unit at price 1.839500, total balance 9947.880400
# hour 297: buy 1 unit at price 1.839000, total balance 9946.041400
# hour 298, sell 1 unit at price 1.836000, investment 10.270270 %, total balance 9947.877400,
# hour 299: buy 1 unit at price 1.820100, total balance 9946.057300
# hour 301: buy 1 unit at price 1.784000, total balance 9944.273300
# hour 302, sell 1 unit at price 1.801000, investment 9.549878 %, total balance 9946.074300,
# hour 303: buy 1 unit at price 1.817000, total balance 9944.257300
# hour 305: buy 1 unit at price 1.841000, total balance 9942.416300
# hour 306, sell 1 unit at price 1.832700, investment 10.270758 %, total balance 9944.249000,
# hour 307: buy 1 unit at price 1.846000, total balance 9942.403000
# hour 308: buy 1 unit at price 1.980700, total balance 9940.422300
# hour 311: buy 1 unit at price 1.955000, total balance 9938.467300
# hour 312: buy 1 unit at price 1.998000, total balance 9936.469300
# hour 313: buy 1 unit at price 2.068000, total balance 9934.401300
# hour 314: buy 1 unit at price 2.059000, total balance 9932.342300
# hour 315: buy 1 unit at price 2.109000, total balance 9930.233300
# hour 317: buy 1 unit at price 2.142000, total balance 9928.091300
# hour 320: buy 1 unit at price 2.301000, total balance 9925.790300
# hour 322: buy 1 unit at price 2.113000, total balance 9923.677300
# hour 323, sell 1 unit at price 2.159000, investment 31.485993 %, total balance 9925.836300,
# hour 324: buy 1 unit at price 2.197000, total balance 9923.639300
# hour 326, sell 1 unit at price 2.249000, investment 36.967113 %, total balance 9925.888300,
# hour 327: buy 1 unit at price 2.245000, total balance 9923.643300
# hour 329, sell 1 unit at price 2.207000, investment 35.815385 %, total balance 9925.850300,
# hour 330, sell 1 unit at price 2.232000, investment 37.497690 %, total balance 9928.082300,
# hour 333: buy 1 unit at price 2.219000, total balance 9925.863300
# hour 335: buy 1 unit at price 2.250000, total balance 9923.613300
# hour 337: buy 1 unit at price 2.174000, total balance 9921.439300
# hour 338, sell 1 unit at price 2.123000, investment 30.887793 %, total balance 9923.562300,
# hour 339, sell 1 unit at price 2.146000, investment 29.129310 %, total balance 9925.708300,
# hour 341, sell 1 unit at price 2.163000, investment 31.011508 %, total balance 9927.871300,
# hour 342: buy 1 unit at price 2.142000, total balance 9925.729300
# hour 344, sell 1 unit at price 2.121900, investment 29.226553 %, total balance 9927.851200,
# hour 345, sell 1 unit at price 2.154000, investment 31.341463 %, total balance 9930.005200,
# hour 346: buy 1 unit at price 2.146000, total balance 9927.859200
# hour 348: buy 1 unit at price 2.161000, total balance 9925.698200
# hour 349, sell 1 unit at price 2.184000, investment 37.358491 %, total balance 9927.882200,
# hour 350: buy 1 unit at price 2.202000, total balance 9925.680200
# hour 352: buy 1 unit at price 2.185000, total balance 9923.495200
# hour 354: buy 1 unit at price 2.180000, total balance 9921.315200
# hour 355, sell 1 unit at price 2.187000, investment 36.516854 %, total balance 9923.502200,
# hour 356: buy 1 unit at price 2.197000, total balance 9921.305200
# hour 358: buy 1 unit at price 2.239000, total balance 9919.066200
# hour 361: buy 1 unit at price 2.295000, total balance 9916.771200
# hour 362: buy 1 unit at price 2.375000, total balance 9914.396200
# hour 365, sell 1 unit at price 2.372000, investment 49.936789 %, total balance 9916.768200,
# hour 369: buy 1 unit at price 2.184000, total balance 9914.584200
# hour 371, sell 1 unit at price 2.171500, investment 37.089646 %, total balance 9916.755700,
# hour 372, sell 1 unit at price 2.144000, investment 27.164887 %, total balance 9918.899700,
# hour 373, sell 1 unit at price 2.158000, investment 19.490587 %, total balance 9921.057700,
# hour 374, sell 1 unit at price 2.144000, investment 17.866960 %, total balance 9923.201700,
# hour 375, sell 1 unit at price 2.134000, investment 16.867470 %, total balance 9925.335700,
# hour 376, sell 1 unit at price 2.146000, investment 18.629077 %, total balance 9927.481700,
# hour 377, sell 1 unit at price 2.169000, investment 22.570072 %, total balance 9929.650700,
# hour 378: buy 1 unit at price 2.187000, total balance 9927.463700
# hour 379: buy 1 unit at price 2.192000, total balance 9925.271700
# hour 380: buy 1 unit at price 2.183000, total balance 9923.088700
# hour 381: buy 1 unit at price 2.164000, total balance 9920.924700
# hour 382: buy 1 unit at price 2.203000, total balance 9918.721700
# hour 383, sell 1 unit at price 2.191000, investment 23.020775 %, total balance 9920.912700,
# hour 384, sell 1 unit at price 2.199000, investment 24.773037 %, total balance 9923.111700,
# hour 385: buy 1 unit at price 2.178000, total balance 9920.933700
# hour 387, sell 1 unit at price 2.202000, investment 23.916714 %, total balance 9923.135700,
# hour 390: buy 1 unit at price 2.189000, total balance 9920.946700
# hour 391, sell 1 unit at price 2.226000, investment 21.905805 %, total balance 9923.172700,
# hour 392, sell 1 unit at price 2.250900, investment 25.050000 %, total balance 9925.423600,
# hour 393: buy 1 unit at price 2.230000, total balance 9923.193600
# hour 395, sell 1 unit at price 2.231000, investment 20.790471 %, total balance 9925.424600,
# hour 396, sell 1 unit at price 2.216500, investment 18.434411 %, total balance 9927.641100,
# hour 397: buy 1 unit at price 2.198000, total balance 9925.443100
# hour 398, sell 1 unit at price 2.243000, investment 23.717595 %, total balance 9927.686100,
# hour 399: buy 1 unit at price 2.216000, total balance 9925.470100
# hour 401: buy 1 unit at price 2.207000, total balance 9923.263100
# hour 402: buy 1 unit at price 2.219000, total balance 9921.044100
# hour 405, sell 1 unit at price 2.204000, investment 20.833333 %, total balance 9923.248100,
# hour 406, sell 1 unit at price 2.168000, investment 19.449036 %, total balance 9925.416100,
# hour 407, sell 1 unit at price 2.154000, investment 17.097037 %, total balance 9927.570100,
# hour 408: buy 1 unit at price 2.164000, total balance 9925.406100
# hour 409, sell 1 unit at price 2.191000, investment 19.140837 %, total balance 9927.597100,
# hour 410, sell 1 unit at price 2.190000, investment 20.323059 %, total balance 9929.787100,
# hour 412, sell 1 unit at price 2.167000, investment 21.468610 %, total balance 9931.954100,
# hour 413, sell 1 unit at price 2.180000, investment 19.977986 %, total balance 9934.134100,
# hour 415: buy 1 unit at price 2.161000, total balance 9931.973100
# hour 417: buy 1 unit at price 2.124000, total balance 9929.849100
# hour 418: buy 1 unit at price 2.108000, total balance 9927.741100
# hour 419, sell 1 unit at price 2.133000, investment 15.860945 %, total balance 9929.874100,
# hour 420, sell 1 unit at price 2.160000, investment 17.009751 %, total balance 9932.034100,
# hour 421, sell 1 unit at price 2.189000, investment 10.516484 %, total balance 9934.223100,
# hour 422: buy 1 unit at price 2.209000, total balance 9932.014100
# hour 424, sell 1 unit at price 2.017000, investment 3.171355 %, total balance 9934.031100,
# hour 425, sell 1 unit at price 2.046000, investment 2.402402 %, total balance 9936.077100,
# hour 426: buy 1 unit at price 2.042000, total balance 9934.035100
# hour 427, sell 1 unit at price 2.026000, investment -2.030948 %, total balance 9936.061100,
# hour 428, sell 1 unit at price 1.988000, investment -3.448276 %, total balance 9938.049100,
# hour 429, sell 1 unit at price 2.008000, investment -4.789000 %, total balance 9940.057100,
# hour 430, sell 1 unit at price 2.005000, investment -6.395892 %, total balance 9942.062100,
# hour 431, sell 1 unit at price 1.972000, investment -14.298131 %, total balance 9944.034100,
# hour 432, sell 1 unit at price 2.001000, investment -5.300521 %, total balance 9946.035100,
# hour 433, sell 1 unit at price 2.018000, investment -8.147474 %, total balance 9948.053100,
# hour 434, sell 1 unit at price 2.040000, investment -9.131403 %, total balance 9950.093100,
# hour 435: buy 1 unit at price 2.039200, total balance 9948.053900
# hour 436, sell 1 unit at price 2.061000, investment -7.120324 %, total balance 9950.114900,
# hour 437: buy 1 unit at price 2.066000, total balance 9948.048900
# hour 438: buy 1 unit at price 2.054000, total balance 9945.994900
# hour 439: buy 1 unit at price 2.038000, total balance 9943.956900
# hour 440, sell 1 unit at price 2.040000, investment -9.333333 %, total balance 9945.996900,
# hour 441: buy 1 unit at price 2.045000, total balance 9943.951900
# hour 442: buy 1 unit at price 2.053000, total balance 9941.898900
# hour 443, sell 1 unit at price 2.027000, investment -6.761730 %, total balance 9943.925900,
# hour 444: buy 1 unit at price 2.028100, total balance 9941.897800
# hour 445, sell 1 unit at price 2.035000, investment -4.995331 %, total balance 9943.932800,
# hour 447, sell 1 unit at price 2.061000, investment -3.960857 %, total balance 9945.993800,
# hour 448, sell 1 unit at price 2.063000, investment -4.534938 %, total balance 9948.056800,
# hour 450: buy 1 unit at price 2.067000, total balance 9945.989800
# hour 451, sell 1 unit at price 2.096000, investment -4.813806 %, total balance 9948.085800,
# hour 452, sell 1 unit at price 2.121000, investment -2.929062 %, total balance 9950.206800,
# hour 455, sell 1 unit at price 2.096000, investment -3.853211 %, total balance 9952.302800,
# hour 456: buy 1 unit at price 2.109000, total balance 9950.193800
# hour 457: buy 1 unit at price 2.121000, total balance 9948.072800
# hour 459, sell 1 unit at price 2.098000, investment -4.506145 %, total balance 9950.170800,
# hour 460, sell 1 unit at price 2.076000, investment -7.280036 %, total balance 9952.246800,
# hour 461: buy 1 unit at price 2.070000, total balance 9950.176800
# hour 462, sell 1 unit at price 2.064000, investment -10.065359 %, total balance 9952.240800,
# hour 463, sell 1 unit at price 2.072000, investment -12.757895 %, total balance 9954.312800,
# hour 465: buy 1 unit at price 2.072000, total balance 9952.240800
# hour 466: buy 1 unit at price 2.076000, total balance 9950.164800
# hour 467, sell 1 unit at price 2.067000, investment -5.357143 %, total balance 9952.231800,
# hour 468: buy 1 unit at price 2.092000, total balance 9950.139800
# hour 470: buy 1 unit at price 2.098000, total balance 9948.041800
# hour 472: buy 1 unit at price 2.148900, total balance 9945.892900
# hour 476: buy 1 unit at price 2.271000, total balance 9943.621900
# hour 477: buy 1 unit at price 2.263000, total balance 9941.358900
# hour 479: buy 1 unit at price 2.388000, total balance 9938.970900
# hour 481: buy 1 unit at price 2.389900, total balance 9936.581000
# hour 483: buy 1 unit at price 2.365000, total balance 9934.216000
# hour 485: buy 1 unit at price 2.347000, total balance 9931.869000
# hour 486: buy 1 unit at price 2.390000, total balance 9929.479000
# hour 488: buy 1 unit at price 2.384000, total balance 9927.095000
# hour 489: buy 1 unit at price 2.406000, total balance 9924.689000
# hour 491, sell 1 unit at price 2.367000, investment 8.230453 %, total balance 9927.056000,
# hour 492: buy 1 unit at price 2.375000, total balance 9924.681000
# hour 494, sell 1 unit at price 2.355000, investment 7.436131 %, total balance 9927.036000,
# hour 496: buy 1 unit at price 2.391000, total balance 9924.645000
# hour 498, sell 1 unit at price 2.411000, investment 10.444343 %, total balance 9927.056000,
# hour 499: buy 1 unit at price 2.399000, total balance 9924.657000
# hour 507, sell 1 unit at price 2.365000, investment 9.288355 %, total balance 9927.022000,
# hour 508, sell 1 unit at price 2.394000, investment 8.669995 %, total balance 9929.416000,
# hour 511: buy 1 unit at price 2.399000, total balance 9927.017000
# hour 514, sell 1 unit at price 2.426000, investment 11.386593 %, total balance 9929.443000,
# hour 515: buy 1 unit at price 2.544000, total balance 9926.899000
# hour 517, sell 1 unit at price 2.496000, investment 14.024669 %, total balance 9929.395000,
# hour 518, sell 1 unit at price 2.535000, investment 13.677130 %, total balance 9931.930000,
# hour 519: buy 1 unit at price 2.500000, total balance 9929.430000
# hour 521, sell 1 unit at price 2.483000, investment 12.966333 %, total balance 9931.913000,
# hour 522, sell 1 unit at price 2.469000, investment 11.416968 %, total balance 9934.382000,
# hour 525, sell 1 unit at price 2.369000, investment 7.340281 %, total balance 9936.751000,
# hour 526, sell 1 unit at price 2.379000, investment 7.210455 %, total balance 9939.130000,
# hour 527: buy 1 unit at price 2.401000, total balance 9936.729000
# hour 528, sell 1 unit at price 2.443000, investment 12.892791 %, total balance 9939.172000,
# hour 529, sell 1 unit at price 2.508000, investment 16.057381 %, total balance 9941.680000,
# hour 530: buy 1 unit at price 2.568300, total balance 9939.111700
# hour 531: buy 1 unit at price 2.678000, total balance 9936.433700
# hour 534: buy 1 unit at price 2.614000, total balance 9933.819700
# hour 535: buy 1 unit at price 2.583000, total balance 9931.236700
# hour 536: buy 1 unit at price 2.571000, total balance 9928.665700
# hour 537, sell 1 unit at price 2.586000, investment 21.751412 %, total balance 9931.251700,
# hour 538: buy 1 unit at price 2.595000, total balance 9928.656700
# hour 540, sell 1 unit at price 2.610000, investment 23.814042 %, total balance 9931.266700,
# hour 541, sell 1 unit at price 2.575000, investment 16.568583 %, total balance 9933.841700,
# hour 543, sell 1 unit at price 2.589000, investment 26.787463 %, total balance 9936.430700,
# hour 544, sell 1 unit at price 2.574000, investment 26.225971 %, total balance 9939.004700,
# hour 546: buy 1 unit at price 2.590000, total balance 9936.414700
# hour 547: buy 1 unit at price 2.576000, total balance 9933.838700
# hour 548: buy 1 unit at price 2.572000, total balance 9931.266700
# hour 550: buy 1 unit at price 2.560000, total balance 9928.706700
# hour 551: buy 1 unit at price 2.544000, total balance 9926.162700
# hour 552, sell 1 unit at price 2.559000, investment 23.862536 %, total balance 9928.721700,
# hour 553, sell 1 unit at price 2.573000, investment 25.267770 %, total balance 9931.294700,
# hour 557, sell 1 unit at price 2.580000, investment 26.594701 %, total balance 9933.874700,
# hour 559: buy 1 unit at price 2.577000, total balance 9931.297700
# hour 560: buy 1 unit at price 2.566000, total balance 9928.731700
# hour 561, sell 1 unit at price 2.535000, investment 23.960880 %, total balance 9931.266700,
# hour 562, sell 1 unit at price 2.536800, investment 23.565514 %, total balance 9933.803500,
# hour 563: buy 1 unit at price 2.529000, total balance 9931.274500
# hour 564, sell 1 unit at price 2.537000, investment 25.092451 %, total balance 9933.811500,
# hour 565, sell 1 unit at price 2.513000, investment 21.577165 %, total balance 9936.324500,
# hour 566, sell 1 unit at price 2.520000, investment 19.487909 %, total balance 9938.844500,
# hour 567, sell 1 unit at price 2.521000, investment 18.859029 %, total balance 9941.365500,
# hour 568, sell 1 unit at price 2.508000, investment 21.159420 %, total balance 9943.873500,
# hour 569: buy 1 unit at price 2.489000, total balance 9941.384500
# hour 570, sell 1 unit at price 2.498000, investment 20.559846 %, total balance 9943.882500,
# hour 571, sell 1 unit at price 2.499000, investment 20.375723 %, total balance 9946.381500,
# hour 573, sell 1 unit at price 2.439000, investment 16.586998 %, total balance 9948.820500,
# hour 574, sell 1 unit at price 2.362000, investment 12.583413 %, total balance 9951.182500,
# hour 575, sell 1 unit at price 2.353000, investment 9.497883 %, total balance 9953.535500,
# hour 576, sell 1 unit at price 2.330000, investment 2.597974 %, total balance 9955.865500,
# hour 577, sell 1 unit at price 2.319000, investment 2.474591 %, total balance 9958.184500,
# hour 578, sell 1 unit at price 2.331000, investment -2.386935 %, total balance 9960.515500,
# hour 579, sell 1 unit at price 2.344000, investment -1.920582 %, total balance 9962.859500,
# hour 580, sell 1 unit at price 2.345000, investment -0.845666 %, total balance 9965.204500,
# hour 581, sell 1 unit at price 2.351000, investment 0.170430 %, total balance 9967.555500,
# hour 582, sell 1 unit at price 2.379000, investment -0.460251 %, total balance 9969.934500,
# hour 585, sell 1 unit at price 2.381000, investment -0.125839 %, total balance 9972.315500,
# hour 586: buy 1 unit at price 2.377000, total balance 9969.938500
# hour 587: buy 1 unit at price 2.360000, total balance 9967.578500
# hour 588: buy 1 unit at price 2.419000, total balance 9965.159500
# hour 589: buy 1 unit at price 2.406000, total balance 9962.753500
# hour 590: buy 1 unit at price 2.372000, total balance 9960.381500
# hour 591, sell 1 unit at price 2.385000, investment -0.872818 %, total balance 9962.766500,
# hour 592, sell 1 unit at price 2.397000, investment 0.926316 %, total balance 9965.163500,
# hour 593, sell 1 unit at price 2.384000, investment -0.292765 %, total balance 9967.547500,
# hour 595: buy 1 unit at price 2.433000, total balance 9965.114500
# hour 596, sell 1 unit at price 2.477000, investment 3.251355 %, total balance 9967.591500,
# hour 597: buy 1 unit at price 2.534000, total balance 9965.057500
# hour 599: buy 1 unit at price 2.544000, total balance 9962.513500
# hour 600: buy 1 unit at price 2.564000, total balance 9959.949500
# hour 601: buy 1 unit at price 2.596000, total balance 9957.353500
# hour 603, sell 1 unit at price 2.571000, investment 7.169654 %, total balance 9959.924500,
# hour 604: buy 1 unit at price 2.582000, total balance 9957.342500
# hour 606: buy 1 unit at price 2.603000, total balance 9954.739500
# hour 608: buy 1 unit at price 2.563000, total balance 9952.176500
# hour 609, sell 1 unit at price 2.551000, investment 0.275157 %, total balance 9954.727500,
# hour 612: buy 1 unit at price 2.558000, total balance 9952.169500
# hour 613: buy 1 unit at price 2.585000, total balance 9949.584500
# hour 614, sell 1 unit at price 2.660000, investment 6.400000 %, total balance 9952.244500,
# hour 617: buy 1 unit at price 2.558000, total balance 9949.686500
# hour 618, sell 1 unit at price 2.556000, investment 6.455643 %, total balance 9952.242500,
# hour 621: buy 1 unit at price 2.526000, total balance 9949.716500
# hour 622, sell 1 unit at price 2.518000, investment -1.958494 %, total balance 9952.234500,
# hour 623: buy 1 unit at price 2.521000, total balance 9949.713500
# hour 625, sell 1 unit at price 2.438000, investment -8.961912 %, total balance 9952.151500,
# hour 626, sell 1 unit at price 2.456000, investment -6.044376 %, total balance 9954.607500,
# hour 627, sell 1 unit at price 2.437000, investment -5.652342 %, total balance 9957.044500,
# hour 629: buy 1 unit at price 2.457000, total balance 9954.587500
# hour 630: buy 1 unit at price 2.451000, total balance 9952.136500
# hour 631: buy 1 unit at price 2.452000, total balance 9949.684500
# hour 632, sell 1 unit at price 2.439000, investment -5.134189 %, total balance 9952.123500,
# hour 634: buy 1 unit at price 2.422000, total balance 9949.701500
# hour 635, sell 1 unit at price 2.416000, investment -6.897881 %, total balance 9952.117500,
# hour 636, sell 1 unit at price 2.415000, investment -6.756757 %, total balance 9954.532500,
# hour 638: buy 1 unit at price 2.452000, total balance 9952.080500
# hour 639, sell 1 unit at price 2.478000, investment -3.804348 %, total balance 9954.558500,
# hour 640: buy 1 unit at price 2.505000, total balance 9952.053500
# hour 642: buy 1 unit at price 2.525000, total balance 9949.528500
# hour 643, sell 1 unit at price 2.539000, investment -1.283048 %, total balance 9952.067500,
# hour 644, sell 1 unit at price 2.536000, investment -0.937500 %, total balance 9954.603500,
# hour 645: buy 1 unit at price 2.546000, total balance 9952.057500
# hour 646: buy 1 unit at price 2.513000, total balance 9949.544500
# hour 648, sell 1 unit at price 2.585000, investment 1.611635 %, total balance 9952.129500,
# hour 649: buy 1 unit at price 2.568000, total balance 9949.561500
# hour 651: buy 1 unit at price 2.636000, total balance 9946.925500
# hour 652: buy 1 unit at price 2.620000, total balance 9944.305500
# hour 654, sell 1 unit at price 2.582000, investment 0.194024 %, total balance 9946.887500,
# hour 655, sell 1 unit at price 2.559000, investment -0.272798 %, total balance 9949.446500,
# hour 656: buy 1 unit at price 2.572000, total balance 9946.874500
# hour 658: buy 1 unit at price 2.533000, total balance 9944.341500
# hour 660: buy 1 unit at price 2.475000, total balance 9941.866500
# hour 661: buy 1 unit at price 2.498000, total balance 9939.368500
# hour 662, sell 1 unit at price 2.450000, investment -3.123764 %, total balance 9941.818500,
# hour 663, sell 1 unit at price 2.473000, investment -0.642828 %, total balance 9944.291500,
# hour 664, sell 1 unit at price 2.476000, investment 4.164914 %, total balance 9946.767500,
# hour 665, sell 1 unit at price 2.471000, investment 4.703390 %, total balance 9949.238500,
# hour 666, sell 1 unit at price 2.463000, investment 1.818933 %, total balance 9951.701500,
# hour 667: buy 1 unit at price 2.481000, total balance 9949.220500
# hour 670, sell 1 unit at price 2.453700, investment 1.982544 %, total balance 9951.674200,
# hour 671: buy 1 unit at price 2.472000, total balance 9949.202200
# hour 672: buy 1 unit at price 2.482000, total balance 9946.720200
# hour 673, sell 1 unit at price 2.498000, investment 5.311973 %, total balance 9949.218200,
# hour 674: buy 1 unit at price 2.491500, total balance 9946.726700
# hour 676: buy 1 unit at price 2.506000, total balance 9944.220700
# hour 677, sell 1 unit at price 2.505000, investment 2.959309 %, total balance 9946.725700,
# hour 678, sell 1 unit at price 2.497000, investment -1.460142 %, total balance 9949.222700,
# hour 679, sell 1 unit at price 2.544000, investment 0.000000 %, total balance 9951.766700,
# hour 680: buy 1 unit at price 2.536000, total balance 9949.230700
# hour 681: buy 1 unit at price 2.551000, total balance 9946.679700
# hour 682, sell 1 unit at price 2.555000, investment -0.351014 %, total balance 9949.234700,
# hour 685: buy 1 unit at price 2.564000, total balance 9946.670700
# hour 686, sell 1 unit at price 2.575000, investment -0.808937 %, total balance 9949.245700,
# hour 687: buy 1 unit at price 2.558000, total balance 9946.687700
# hour 689, sell 1 unit at price 2.582200, investment 0.007746 %, total balance 9949.269900,
# hour 693: buy 1 unit at price 2.586000, total balance 9946.683900
# hour 694: buy 1 unit at price 2.572000, total balance 9944.111900
# hour 695: buy 1 unit at price 2.571000, total balance 9941.540900
# hour 697, sell 1 unit at price 2.521000, investment -3.150211 %, total balance 9944.061900,
# hour 699: buy 1 unit at price 2.524000, total balance 9941.537900
# hour 700, sell 1 unit at price 2.524700, investment -1.494343 %, total balance 9944.062600,
# hour 701, sell 1 unit at price 2.532000, investment -1.016419 %, total balance 9946.594600,
# hour 702, sell 1 unit at price 2.510000, investment -2.901354 %, total balance 9949.104600,
# hour 703, sell 1 unit at price 2.510000, investment -1.876466 %, total balance 9951.614600,
# hour 706, sell 1 unit at price 2.394000, investment -5.225653 %, total balance 9954.008600,
# hour 707, sell 1 unit at price 2.382000, investment -5.513685 %, total balance 9956.390600,
# hour 708: buy 1 unit at price 2.380000, total balance 9954.010600
# hour 709: buy 1 unit at price 2.378000, total balance 9951.632600
# hour 710, sell 1 unit at price 2.420000, investment -1.505902 %, total balance 9954.052600,
# hour 711, sell 1 unit at price 2.394000, investment -2.325581 %, total balance 9956.446600,
# hour 712, sell 1 unit at price 2.395000, investment -2.324633 %, total balance 9958.841600,
# hour 713, sell 1 unit at price 2.383000, investment -1.610239 %, total balance 9961.224600,
# hour 714, sell 1 unit at price 2.382000, investment -2.854812 %, total balance 9963.606600,
# hour 715: buy 1 unit at price 2.298000, total balance 9961.308600
# hour 716, sell 1 unit at price 2.280000, investment -8.982036 %, total balance 9963.588600,
# hour 717, sell 1 unit at price 2.287000, investment -9.425743 %, total balance 9965.875600,
# hour 718, sell 1 unit at price 2.280000, investment -10.447761 %, total balance 9968.155600,
# hour 719: buy 1 unit at price 2.306000, total balance 9965.849600
# hour 720, sell 1 unit at price 2.301000, investment -8.436132 %, total balance 9968.150600,
# hour 721, sell 1 unit at price 2.314000, investment -9.890966 %, total balance 9970.464600,
# hour 722, sell 1 unit at price 2.313000, investment -12.253414 %, total balance 9972.777600,
# hour 724, sell 1 unit at price 2.321000, investment -11.412214 %, total balance 9975.098600,
# hour 725, sell 1 unit at price 2.280000, investment -11.353033 %, total balance 9977.378600,
# hour 726, sell 1 unit at price 2.287000, investment -9.711804 %, total balance 9979.665600,
# hour 727: buy 1 unit at price 2.331000, total balance 9977.334600
# hour 729: buy 1 unit at price 2.313000, total balance 9975.021600
# hour 730: buy 1 unit at price 2.292000, total balance 9972.729600
# hour 731: buy 1 unit at price 2.305000, total balance 9970.424600
# hour 732: buy 1 unit at price 2.310000, total balance 9968.114600
# hour 733, sell 1 unit at price 2.353000, investment -4.929293 %, total balance 9970.467600,
# hour 734, sell 1 unit at price 2.330000, investment -6.725380 %, total balance 9972.797600,
# hour 735, sell 1 unit at price 2.343000, investment -5.562273 %, total balance 9975.140600,
# hour 736: buy 1 unit at price 2.343000, total balance 9972.797600
# hour 738: buy 1 unit at price 2.359000, total balance 9970.438600
# hour 739, sell 1 unit at price 2.355000, investment -4.733010 %, total balance 9972.793600,
# hour 740, sell 1 unit at price 2.341000, investment -5.680902 %, total balance 9975.134600,
# hour 742: buy 1 unit at price 2.333000, total balance 9972.801600
# hour 744, sell 1 unit at price 2.311000, investment -7.244632 %, total balance 9975.112600,
# hour 745, sell 1 unit at price 2.311000, investment -7.781325 %, total balance 9977.423600,
# hour 746, sell 1 unit at price 2.313000, investment -8.793375 %, total balance 9979.736600,
# hour 747: buy 1 unit at price 2.311000, total balance 9977.425600
# hour 749, sell 1 unit at price 2.290000, investment -10.231282 %, total balance 9979.715600,
# hour 752, sell 1 unit at price 2.232000, investment -12.948518 %, total balance 9981.947600,
# hour 753: buy 1 unit at price 2.236000, total balance 9979.711600
# hour 754, sell 1 unit at price 2.236000, investment -12.587959 %, total balance 9981.947600,
# hour 755, sell 1 unit at price 2.255000, investment -12.799691 %, total balance 9984.202600,
# hour 757, sell 1 unit at price 2.252000, investment -12.441680 %, total balance 9986.454600,
# hour 758, sell 1 unit at price 2.249000, investment -12.524310 %, total balance 9988.703600,
# hour 760, sell 1 unit at price 2.192000, investment -13.153724 %, total balance 9990.895600,
# hour 761, sell 1 unit at price 2.185000, investment -8.193277 %, total balance 9993.080600,
# hour 762: buy 1 unit at price 2.212000, total balance 9990.868600
# hour 763: buy 1 unit at price 2.321000, total balance 9988.547600
# hour 764: buy 1 unit at price 2.383000, total balance 9986.164600
# hour 765: buy 1 unit at price 2.389000, total balance 9983.775600
# hour 766: buy 1 unit at price 2.409000, total balance 9981.366600
# hour 767: buy 1 unit at price 2.425000, total balance 9978.941600
# hour 768: buy 1 unit at price 2.486000, total balance 9976.455600
# hour 770, sell 1 unit at price 2.460000, investment 3.448276 %, total balance 9978.915600,
# hour 771: buy 1 unit at price 2.465000, total balance 9976.450600
# hour 772: buy 1 unit at price 2.477000, total balance 9973.973600
# hour 773: buy 1 unit at price 2.468000, total balance 9971.505600
# hour 775: buy 1 unit at price 2.434000, total balance 9969.071600
# hour 776, sell 1 unit at price 2.455000, investment 6.832028 %, total balance 9971.526600,
# hour 777: buy 1 unit at price 2.476000, total balance 9969.050600
# hour 778, sell 1 unit at price 2.461000, investment 6.721596 %, total balance 9971.511600,
# hour 780: buy 1 unit at price 2.492000, total balance 9969.019600
# hour 781: buy 1 unit at price 2.505000, total balance 9966.514600
# hour 783, sell 1 unit at price 2.503000, investment 7.378807 %, total balance 9969.017600,
# hour 784: buy 1 unit at price 2.523000, total balance 9966.494600
# hour 791, sell 1 unit at price 2.443000, investment 5.620406 %, total balance 9968.937600,
# hour 792: buy 1 unit at price 2.437000, total balance 9966.500600
# hour 793: buy 1 unit at price 2.429000, total balance 9964.071600
# hour 794, sell 1 unit at price 2.423000, investment 5.715532 %, total balance 9966.494600,
# hour 795, sell 1 unit at price 2.433000, investment 5.553145 %, total balance 9968.927600,
# hour 797: buy 1 unit at price 2.452000, total balance 9966.475600
# hour 798, sell 1 unit at price 2.439000, investment 5.584416 %, total balance 9968.914600,
# hour 799, sell 1 unit at price 2.421000, investment 3.329065 %, total balance 9971.335600,
# hour 800: buy 1 unit at price 2.435000, total balance 9968.900600
# hour 801: buy 1 unit at price 2.438000, total balance 9966.462600
# hour 803: buy 1 unit at price 2.478000, total balance 9963.984600
# hour 805: buy 1 unit at price 2.440000, total balance 9961.544600
# hour 806, sell 1 unit at price 2.474000, investment 4.874947 %, total balance 9964.018600,
# hour 807: buy 1 unit at price 2.496000, total balance 9961.522600
# hour 809, sell 1 unit at price 2.497000, investment 7.029576 %, total balance 9964.019600,
# hour 810: buy 1 unit at price 2.491000, total balance 9961.528600
# hour 812: buy 1 unit at price 2.469000, total balance 9959.059600
# hour 813, sell 1 unit at price 2.477000, investment 7.183038 %, total balance 9961.536600,
# hour 814: buy 1 unit at price 2.504000, total balance 9959.032600
# hour 816: buy 1 unit at price 2.501000, total balance 9956.531600
# hour 817, sell 1 unit at price 2.474000, investment 10.644007 %, total balance 9959.005600,
# hour 818, sell 1 unit at price 2.487000, investment 12.432188 %, total balance 9961.492600,
# hour 819: buy 1 unit at price 2.468000, total balance 9959.024600
# hour 821, sell 1 unit at price 2.440000, investment 5.127100 %, total balance 9961.464600,
# hour 822, sell 1 unit at price 2.455000, investment 3.021402 %, total balance 9963.919600,
# hour 823: buy 1 unit at price 2.452000, total balance 9961.467600
# hour 825, sell 1 unit at price 2.457000, investment 2.846379 %, total balance 9963.924600,
# hour 826: buy 1 unit at price 2.474000, total balance 9961.450600
# hour 827, sell 1 unit at price 2.475000, investment 2.739726 %, total balance 9963.925600,
# hour 828, sell 1 unit at price 2.489000, investment 2.639175 %, total balance 9966.414600,
# hour 829, sell 1 unit at price 2.509000, investment 0.925181 %, total balance 9968.923600,
# hour 832: buy 1 unit at price 2.534000, total balance 9966.389600
# hour 833: buy 1 unit at price 2.556000, total balance 9963.833600
# hour 835: buy 1 unit at price 2.537000, total balance 9961.296600
# hour 836, sell 1 unit at price 2.528000, investment 2.555781 %, total balance 9963.824600,
# hour 837: buy 1 unit at price 2.531000, total balance 9961.293600
# hour 838: buy 1 unit at price 2.528000, total balance 9958.765600
# hour 840, sell 1 unit at price 2.498000, investment 0.847800 %, total balance 9961.263600,
# hour 841, sell 1 unit at price 2.529800, investment 2.504052 %, total balance 9963.793400,
# hour 843, sell 1 unit at price 2.520000, investment 3.533279 %, total balance 9966.313400,
# hour 844, sell 1 unit at price 2.518000, investment 1.696284 %, total balance 9968.831400,
# hour 845, sell 1 unit at price 2.512000, investment 0.802568 %, total balance 9971.343400,
# hour 846, sell 1 unit at price 2.519000, investment 0.558882 %, total balance 9973.862400,
# hour 847, sell 1 unit at price 2.522000, investment -0.039635 %, total balance 9976.384400,
# hour 848, sell 1 unit at price 2.535000, investment 4.021338 %, total balance 9978.919400,
# hour 850: buy 1 unit at price 2.528000, total balance 9976.391400
# hour 851: buy 1 unit at price 2.513000, total balance 9973.878400
# hour 853, sell 1 unit at price 2.276000, investment -6.298888 %, total balance 9976.154400,
# hour 854, sell 1 unit at price 2.260000, investment -7.830343 %, total balance 9978.414400,
# hour 855, sell 1 unit at price 2.263000, investment -7.063655 %, total balance 9980.677400,
# hour 856, sell 1 unit at price 2.277000, investment -6.603774 %, total balance 9982.954400,
# hour 857, sell 1 unit at price 2.259000, investment -8.837772 %, total balance 9985.213400,
# hour 858, sell 1 unit at price 2.252700, investment -7.676230 %, total balance 9987.466100,
# hour 859, sell 1 unit at price 2.245000, investment -10.056090 %, total balance 9989.711100,
# hour 860, sell 1 unit at price 2.251000, investment -9.634685 %, total balance 9991.962100,
# ...
# hour 978: buy 1 unit at price 2.046000, total balance 10010.886400
# hour 980, sell 1 unit at price 2.040000, investment -0.970874 %, total balance 10012.926400,
# hour 981, sell 1 unit at price 2.018000, investment -0.640079 %, total balance 10014.944400,
# hour 983, sell 1 unit at price 1.991000, investment -4.324844 %, total balance 10016.935400,
# hour 984, sell 1 unit at price 2.008000, investment -1.857283 %, total balance 10018.943400,
# hour 989: buy 1 unit at price 2.002500, total balance 10016.940900
# hour 991, sell 1 unit at price 1.953000, investment -2.471910 %, total balance 10018.893900,
# hour 993: buy 1 unit at price 1.970000, total balance 10016.923900
# hour 994: buy 1 unit at price 1.982000, total balance 10014.941900
# hour 995, sell 1 unit at price 2.000000, investment 1.522843 %, total balance 10016.941900,
# hour 996: buy 1 unit at price 2.007300, total balance 10014.934600
# hour 998, sell 1 unit at price 1.991000, investment 0.454087 %, total balance 10016.925600,
# hour 999, sell 1 unit at price 1.988000, investment -0.961491 %, total balance 10018.913600,
# hour 1002: buy 1 unit at price 1.946000, total balance 10016.967600
# hour 1003, sell 1 unit at price 1.914000, investment -1.644399 %, total balance 10018.881600,
# hour 1004: buy 1 unit at price 1.929000, total balance 10016.952600
# hour 1005, sell 1 unit at price 1.933000, investment 0.207361 %, total balance 10018.885600,
# hour 1009: buy 1 unit at price 1.895000, total balance 10016.990600
# hour 1010, sell 1 unit at price 1.887000, investment -0.422164 %, total balance 10018.877600,
# hour 1013: buy 1 unit at price 1.909900, total balance 10016.967700
# hour 1014, sell 1 unit at price 1.890000, investment -1.041939 %, total balance 10018.857700,
# hour 1015: buy 1 unit at price 1.895000, total balance 10016.962700
# hour 1017: buy 1 unit at price 1.878000, total balance 10015.084700
# hour 1018, sell 1 unit at price 1.838000, investment -3.007916 %, total balance 10016.922700,
# hour 1019, sell 1 unit at price 1.841000, investment -1.970181 %, total balance 10018.763700,
# hour 1022: buy 1 unit at price 1.883000, total balance 10016.880700
# hour 1023, sell 1 unit at price 1.875000, investment -0.424854 %, total balance 10018.755700,
# hour 1026: buy 1 unit at price 1.877000, total balance 10016.878700
# hour 1028: buy 1 unit at price 1.860000, total balance 10015.018700
# hour 1029, sell 1 unit at price 1.857000, investment -1.065530 %, total balance 10016.875700,
# hour 1030: buy 1 unit at price 1.866000, total balance 10015.009700
# hour 1031: buy 1 unit at price 1.882000, total balance 10013.127700
# hour 1032, sell 1 unit at price 1.866000, investment 0.322581 %, total balance 10014.993700,
# hour 1033, sell 1 unit at price 1.890000, investment 1.286174 %, total balance 10016.883700,
# hour 1034, sell 1 unit at price 1.899000, investment 0.903294 %, total balance 10018.782700,
# hour 1035: buy 1 unit at price 1.882000, total balance 10016.900700
# hour 1036: buy 1 unit at price 1.876000, total balance 10015.024700
# hour 1037, sell 1 unit at price 1.890000, investment 0.425080 %, total balance 10016.914700,
# hour 1038, sell 1 unit at price 1.841000, investment -1.865672 %, total balance 10018.755700,
# hour 1052: buy 1 unit at price 1.794000, total balance 10016.961700
# hour 1054: buy 1 unit at price 1.688000, total balance 10015.273700
# hour 1055, sell 1 unit at price 1.727000, investment -3.734671 %, total balance 10017.000700,
# hour 1056, sell 1 unit at price 1.754000, investment 3.909953 %, total balance 10018.754700,
# hour 1062: buy 1 unit at price 1.755000, total balance 10016.999700
# hour 1063, sell 1 unit at price 1.779000, investment 1.367521 %, total balance 10018.778700,
# hour 1065: buy 1 unit at price 1.779000, total balance 10016.999700
# hour 1066: buy 1 unit at price 1.799000, total balance 10015.200700
# hour 1067, sell 1 unit at price 1.803000, investment 1.349073 %, total balance 10017.003700,
# hour 1068: buy 1 unit at price 1.823000, total balance 10015.180700
# hour 1069, sell 1 unit at price 1.872000, investment 4.057810 %, total balance 10017.052700,
# hour 1070, sell 1 unit at price 1.835100, investment 0.663741 %, total balance 10018.887800,
# hour 1071: buy 1 unit at price 1.832000, total balance 10017.055800
# hour 1072: buy 1 unit at price 1.815000, total balance 10015.240800
# hour 1076, sell 1 unit at price 1.761600, investment -3.842795 %, total balance 10017.002400,
# hour 1077, sell 1 unit at price 1.767000, investment -2.644628 %, total balance 10018.769400,
# hour 1085: buy 1 unit at price 1.747000, total balance 10017.022400
# hour 1086: buy 1 unit at price 1.751000, total balance 10015.271400
# hour 1087: buy 1 unit at price 1.745000, total balance 10013.526400
# hour 1088: buy 1 unit at price 1.781000, total balance 10011.745400
# hour 1089: buy 1 unit at price 1.767000, total balance 10009.978400
# hour 1091, sell 1 unit at price 1.809000, investment 3.548941 %, total balance 10011.787400,
# hour 1092, sell 1 unit at price 1.785000, investment 1.941748 %, total balance 10013.572400,
# hour 1094, sell 1 unit at price 1.797000, investment 2.979943 %, total balance 10015.369400,
# hour 1095, sell 1 unit at price 1.801000, investment 1.122965 %, total balance 10017.170400,
# hour 1097: buy 1 unit at price 1.825000, total balance 10015.345400
# hour 1098, sell 1 unit at price 1.821000, investment 3.056027 %, total balance 10017.166400,
# hour 1099, sell 1 unit at price 1.800100, investment -1.364384 %, total balance 10018.966500,
# hour 1102: buy 1 unit at price 1.822000, total balance 10017.144500
# hour 1103, sell 1 unit at price 1.815000, investment -0.384193 %, total balance 10018.959500,
# hour 1105: buy 1 unit at price 1.804000, total balance 10017.155500
# hour 1106, sell 1 unit at price 1.780100, investment -1.324834 %, total balance 10018.935600,
# hour 1108: buy 1 unit at price 1.812000, total balance 10017.123600
# hour 1109, sell 1 unit at price 1.865000, investment 2.924945 %, total balance 10018.988600,
# hour 1112: buy 1 unit at price 1.899000, total balance 10017.089600
# hour 1114: buy 1 unit at price 1.912000, total balance 10015.177600
# hour 1116: buy 1 unit at price 1.985000, total balance 10013.192600
# hour 1117: buy 1 unit at price 1.977000, total balance 10011.215600
# hour 1119: buy 1 unit at price 1.952000, total balance 10009.263600
# hour 1120: buy 1 unit at price 1.969000, total balance 10007.294600
# hour 1123, sell 1 unit at price 1.979000, investment 4.212744 %, total balance 10009.273600,
# hour 1125: buy 1 unit at price 1.911100, total balance 10007.362500
# hour 1126: buy 1 unit at price 1.936000, total balance 10005.426500
# hour 1127, sell 1 unit at price 1.929000, investment 0.889121 %, total balance 10007.355500,
# hour 1128, sell 1 unit at price 1.914000, investment -3.576826 %, total balance 10009.269500,
# hour 1129: buy 1 unit at price 1.952000, total balance 10007.317500
# hour 1130, sell 1 unit at price 2.021000, investment 2.225594 %, total balance 10009.338500,
# hour 1133: buy 1 unit at price 2.013000, total balance 10007.325500
# hour 1138: buy 1 unit at price 2.048000, total balance 10005.277500
# hour 1139: buy 1 unit at price 2.044000, total balance 10003.233500
# hour 1140: buy 1 unit at price 2.033000, total balance 10001.200500
# hour 1141, sell 1 unit at price 2.036000, investment 4.303279 %, total balance 10003.236500,
# hour 1142, sell 1 unit at price 2.023000, investment 2.742509 %, total balance 10005.259500,
# hour 1144, sell 1 unit at price 2.042000, investment 6.849458 %, total balance 10007.301500,
# hour 1145, sell 1 unit at price 2.032000, investment 4.958678 %, total balance 10009.333500,
# hour 1146: buy 1 unit at price 2.029000, total balance 10007.304500
# hour 1147, sell 1 unit at price 2.010000, investment 2.971311 %, total balance 10009.314500,
# hour 1148, sell 1 unit at price 2.014000, investment 0.049677 %, total balance 10011.328500,
# hour 1149: buy 1 unit at price 2.015000, total balance 10009.313500
# hour 1150: buy 1 unit at price 2.018000, total balance 10007.295500
# hour 1152, sell 1 unit at price 2.119000, investment 3.466797 %, total balance 10009.414500,
# hour 1153: buy 1 unit at price 2.159000, total balance 10007.255500
# hour 1155: buy 1 unit at price 2.194000, total balance 10005.061500
# hour 1156, sell 1 unit at price 2.182000, investment 6.751468 %, total balance 10007.243500,
# hour 1159, sell 1 unit at price 2.158000, investment 6.148549 %, total balance 10009.401500,
# hour 1161: buy 1 unit at price 2.107000, total balance 10007.294500
# hour 1162: buy 1 unit at price 2.123000, total balance 10005.171500
# hour 1163, sell 1 unit at price 2.124000, investment 4.682109 %, total balance 10007.295500,
# hour 1164, sell 1 unit at price 2.124000, investment 5.409429 %, total balance 10009.419500,
# hour 1165, sell 1 unit at price 2.149000, investment 6.491576 %, total balance 10011.568500,
# hour 1166, sell 1 unit at price 2.147200, investment -0.546549 %, total balance 10013.715700,
# hour 1167, sell 1 unit at price 2.142000, investment -2.370100 %, total balance 10015.857700,
# hour 1168: buy 1 unit at price 2.146000, total balance 10013.711700
# hour 1169: buy 1 unit at price 2.136000, total balance 10011.575700
# hour 1171: buy 1 unit at price 2.138000, total balance 10009.437700
# hour 1172: buy 1 unit at price 2.110700, total balance 10007.327000
# hour 1174, sell 1 unit at price 2.079000, investment -1.328904 %, total balance 10009.406000,
# hour 1175, sell 1 unit at price 2.059000, investment -3.014602 %, total balance 10011.465000,
# hour 1177, sell 1 unit at price 2.028000, investment -5.498602 %, total balance 10013.493000,
# hour 1178, sell 1 unit at price 2.009500, investment -5.922285 %, total balance 10015.502500,
# hour 1180, sell 1 unit at price 1.882800, investment -11.936389 %, total balance 10017.385300,
# hour 1181, sell 1 unit at price 1.911000, investment -9.461316 %, total balance 10019.296300,
# hour 1187: buy 1 unit at price 1.927000, total balance 10017.369300
# hour 1188, sell 1 unit at price 1.901000, investment -1.349248 %, total balance 10019.270300,
# hour 1190: buy 1 unit at price 1.949000, total balance 10017.321300
# hour 1191: buy 1 unit at price 1.940100, total balance 10015.381200
# hour 1193: buy 1 unit at price 1.945000, total balance 10013.436200
# hour 1194: buy 1 unit at price 1.951000, total balance 10011.485200
# hour 1196, sell 1 unit at price 1.955000, investment 0.307850 %, total balance 10013.440200,
# hour 1197, sell 1 unit at price 1.954000, investment 0.716458 %, total balance 10015.394200,
# hour 1199: buy 1 unit at price 1.975100, total balance 10013.419100
# hour 1201: buy 1 unit at price 1.949000, total balance 10011.470100
# hour 1202, sell 1 unit at price 1.953000, investment 0.411311 %, total balance 10013.423100,
# hour 1203, sell 1 unit at price 1.959000, investment 0.410046 %, total balance 10015.382100,
# hour 1204, sell 1 unit at price 1.954000, investment -1.068300 %, total balance 10017.336100,
# hour 1206: buy 1 unit at price 1.948000, total balance 10015.388100
# hour 1207, sell 1 unit at price 1.974600, investment 1.313494 %, total balance 10017.362700,
# hour 1208, sell 1 unit at price 1.938000, investment -0.513347 %, total balance 10019.300700,
# hour 1210: buy 1 unit at price 1.965800, total balance 10017.334900
# hour 1213: buy 1 unit at price 2.001300, total balance 10015.333600
# hour 1214: buy 1 unit at price 2.000000, total balance 10013.333600
# hour 1216, sell 1 unit at price 2.006000, investment 2.044969 %, total balance 10015.339600,
# hour 1217, sell 1 unit at price 2.002000, investment 0.034977 %, total balance 10017.341600,
# hour 1218: buy 1 unit at price 2.033000, total balance 10015.308600
# hour 1220, sell 1 unit at price 2.019000, investment 0.950000 %, total balance 10017.327600,
# hour 1221: buy 1 unit at price 2.039000, total balance 10015.288600
# hour 1222: buy 1 unit at price 2.081000, total balance 10013.207600
# hour 1224, sell 1 unit at price 2.069000, investment 1.770782 %, total balance 10015.276600,
# hour 1225, sell 1 unit at price 2.060000, investment 1.029917 %, total balance 10017.336600,
# hour 1227: buy 1 unit at price 2.027000, total balance 10015.309600
# hour 1228, sell 1 unit at price 2.031000, investment -2.402691 %, total balance 10017.340600,
# hour 1229, sell 1 unit at price 2.050000, investment 1.134682 %, total balance 10019.390600,
# hour 1230: buy 1 unit at price 2.060000, total balance 10017.330600
# hour 1232: buy 1 unit at price 2.073000, total balance 10015.257600
# hour 1233, sell 1 unit at price 2.102000, investment 2.038835 %, total balance 10017.359600,
# hour 1238: buy 1 unit at price 2.181000, total balance 10015.178600
# hour 1239: buy 1 unit at price 2.201000, total balance 10012.977600
# hour 1242: buy 1 unit at price 2.188000, total balance 10010.789600
# hour 1243, sell 1 unit at price 2.196000, investment 5.933430 %, total balance 10012.985600,
# hour 1244, sell 1 unit at price 2.177000, investment -0.183402 %, total balance 10015.162600,
# hour 1246: buy 1 unit at price 2.195000, total balance 10012.967600
# hour 1248, sell 1 unit at price 2.206000, investment 0.227169 %, total balance 10015.173600,
# hour 1250, sell 1 unit at price 2.177000, investment -0.502742 %, total balance 10017.350600,
# hour 1251: buy 1 unit at price 2.122000, total balance 10015.228600
# hour 1252: buy 1 unit at price 2.130000, total balance 10013.098600
# hour 1253: buy 1 unit at price 2.107000, total balance 10010.991600
# hour 1254, sell 1 unit at price 2.133000, investment -2.824601 %, total balance 10013.124600,
# hour 1255: buy 1 unit at price 2.124000, total balance 10011.000600
# hour 1256, sell 1 unit at price 2.142000, investment 0.942507 %, total balance 10013.142600,
# hour 1257, sell 1 unit at price 2.115200, investment -0.694836 %, total balance 10015.257800,
# hour 1259, sell 1 unit at price 2.080500, investment -1.257712 %, total balance 10017.338300,
# hour 1260, sell 1 unit at price 2.127000, investment 0.141243 %, total balance 10019.465300,
# hour 1263: buy 1 unit at price 2.156000, total balance 10017.309300
# hour 1265: buy 1 unit at price 2.133000, total balance 10015.176300
# hour 1267: buy 1 unit at price 2.117000, total balance 10013.059300
# hour 1268, sell 1 unit at price 2.116000, investment -1.855288 %, total balance 10015.175300,
# hour 1269: buy 1 unit at price 2.152000, total balance 10013.023300
# hour 1271, sell 1 unit at price 2.144000, investment 0.515706 %, total balance 10015.167300,
# hour 1272: buy 1 unit at price 2.127000, total balance 10013.040300
# hour 1273, sell 1 unit at price 2.134000, investment 0.803023 %, total balance 10015.174300,
# hour 1274: buy 1 unit at price 2.138000, total balance 10013.036300
# hour 1275, sell 1 unit at price 2.149000, investment -0.139405 %, total balance 10015.185300,
# hour 1276: buy 1 unit at price 2.172000, total balance 10013.013300
# hour 1278: buy 1 unit at price 2.186000, total balance 10010.827300
# hour 1280: buy 1 unit at price 2.131500, total balance 10008.695800
# hour 1281, sell 1 unit at price 2.127000, investment 0.000000 %, total balance 10010.822800,
# hour 1282, sell 1 unit at price 2.148000, investment 0.467727 %, total balance 10012.970800,
# hour 1284: buy 1 unit at price 2.125200, total balance 10010.845600
# hour 1286, sell 1 unit at price 2.140200, investment -1.464088 %, total balance 10012.985800,
# hour 1288, sell 1 unit at price 2.048300, investment -6.299177 %, total balance 10015.034100,
# hour 1289, sell 1 unit at price 2.072000, investment -2.791461 %, total balance 10017.106100,
# hour 1290, sell 1 unit at price 2.067000, investment -2.738566 %, total balance 10019.173100,
# hour 1298: buy 1 unit at price 2.068000, total balance 10017.105100
# hour 1299, sell 1 unit at price 2.051000, investment -0.822050 %, total balance 10019.156100,
# hour 1301: buy 1 unit at price 2.002000, total balance 10017.154100
# hour 1302, sell 1 unit at price 2.023000, investment 1.048951 %, total balance 10019.177100,
# hour 1305: buy 1 unit at price 2.022000, total balance 10017.155100
# hour 1306, sell 1 unit at price 2.014000, investment -0.395648 %, total balance 10019.169100,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
